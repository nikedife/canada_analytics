# %% [markdown]
# # 1. Commercial properties.
# A commercial real estate company evaluates vacancy rates, square footage, rental rates, and
# operating expenses for commercial properties in a large metropolitan area in order to provide
# clients with quantitative information upon which to make rental decisions. The data below are
# taken from suburban commercial properties that are the newest, best located, most attractive,
# and expensive for five specific geographic areas. First column is rental rates, second column is the
# age of properties, third column is the operating expenses and taxes, fourth column is the vacancy
# rates and last column is the total square footage.
# (Data are sampled comes from: Applied Linear Regression Models, written by Michael H. Kutner,
# Christopher J. Nachtsheim & John Neter)
#
# (a) What is response variable? What are the predictors?
#
# (b) Calculate the mean, median, standard deviation of rental rates. Comment on your calculation.
#
# (c) Draw boxplot for age of properties, operating expenses and taxes,vacancy rates and total
# square footage, what are your findings based on the boxplot?
#
#
# (d) Draw histogram for age of properties, operating expenses and taxes,vacancy rates and total
# square footage, what are your findings based on the histogram?
#
#
# (e) Is age of properties normally distributed? Verify your answer.
#
#
# (f ) Is there a correlation between response variable and predictors? Draw scatter plot between
# response variable and each of predictors, and calculate correlation coefficient. What are your
# findings?
#
#
# (g) Normalize the age of properties based on z−score normalization.
#
#
# (h) Normalize the age of properties by z−score normalization using mean absolute deviation
# instead of standard deviation.
#
#
# (i) Comment on the methods you used in (g) and (h).

# %% [markdown]
# # Answer to the first question.
#
#
# (a) Variables of interest in an experiment (those that are measured or observed) are called response or dependent variables. while predictors are called independent variables or a variable used to estimate, forecast, or project future events or circumstances.

# %% [markdown]
# # Answer to the second question.
#
#
# (b) Calculate the mean, median, standard deviation of rental rates. Comment on your calculation.
#
# i) mean is 15.170769230769231
# ii) median is 15.0
# iii) standard deviation is 1.6043250213215718
#
# The mean and median of the rental rates is almost the same meaning that this is definitely a gaussian distribution which is bell liked shape.The value of the standard deviation signifies that the 65% of the data is within the first standard deviation

# %% [markdown]
# # Answer to the Third question.
#
#
# (c) Draw boxplot for age of properties, operating expenses and taxes,vacancy rates and total square footage, what are your findings based on the boxplot?

# %%
# lets generate box plots for the above subject predictors using our python package
df.boxplot()

# As you can see from our findings there are no outliers so our data is looking very good.
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Answer to the fourth question.
#
#
# (d) Draw histogram for age of properties, operating expenses and taxes,vacancy rates and total square footage, what are your findings based on the histogram?

# %%
# lets generate histograms for the above subject predictors using our python package

df['Age'].plot.hist()

# from the data we can see that it doesnt obey a normal distribution
# data is skewed
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# lets generate histograms for the above subject predictors using our python package
df['Footage'].plot.hist()
# from the data we can see that it doesnt obey a normal distribution
# data is skewed
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# lets generate histograms for the above subject predictors using our python package
df['Vacancy'].plot.hist()
# from the data we can see that it doesnt obey a normal distribution
# data is skewed
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# lets generate histograms for the above subject predictors using our python package
df['Expense'].plot.hist()
# from the data we can see that it doesnt obey a normal distribution
# data is skewed
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Answer to the fifth question.
#
#
# (e) Is age of properties normally distributed? Verify your answer.
#
# The age properties is not normally distributed based on the histogram visualisation above

# %% [markdown]
# # Answer to the sixth question.
#
#
# (f)Is there a correlation between response variable and predictors? Draw scatter plot between response variable and each of predictors, and calculate correlation coefficient. What are your findings?
#
# # There is a correlation between the rental rate and the age,vacancy,footage and expenses
# #The correlation is positive for vacancy,footage and expenses which means that as the vacancy,footage,expenses increases the rentalrate increases also.
# #There is a negative correlation between age and rental rate which means as age increases rental rate decreases or vice versa.see the correlation coefficients below.
# Age 	   -0.243400
# Expense 	0.370501
# Vacancy 	0.241841
# Footage 	0.571105

# %%
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Visualizing for the correlation between response variable and predictors
plt.figure(figsize=(15,8), facecolor='blue')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if plotnumber<=5:#since there are 5 features
        ax = plt.subplot(2,3,plotnumber)#2,3 means arrange the graphs in 2-rows and 3-columns spaces as seen below while plotnumber means plot graphs
        sns.scatterplot(df[column],df['RentalRate'])#performing a distribution plot for all the columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# lets get the correlation coefficients
df.corr()
# Out:
#             RentalRate       Age   Expense   Vacancy   Footage
# RentalRate    1.000000 -0.243400  0.370501  0.241841  0.571105
# Age          -0.243400  1.000000  0.413150 -0.274659  0.258523
# Expense       0.370501  0.413150  1.000000 -0.336962  0.441669
# Vacancy       0.241841 -0.274659 -0.336962  1.000000  0.157719
# Footage       0.571105  0.258523  0.441669  0.157719  1.000000

# %% [markdown]
# # Answer to the seventh question.
#
# (g) Normalize the age of properties based on z−score normalization
#
# As we can see we have normalised using zscore and from the data below the mean is zero and the standard deviation is one.please look at the age_zscore column.its the normalised data

# %%
from scipy.stats import zscore
df['Age_zscore'] = zscore(df['Age'])

df.describe()
# Out:
#        RentalRate        Age    Expense    Vacancy        Footage  \
# count   65.000000  65.000000  65.000000  65.000000      65.000000
# mean    15.170769   8.030769   9.602308   0.074615  151664.907692
# std      1.604325   6.779955   2.653303   0.139531  105557.951613
# min     10.500000   0.000000   3.000000   0.000000   27000.000000
# 25%     14.000000   2.000000   7.960000   0.000000   60000.000000
# 50%     15.000000   4.000000  10.380000   0.030000  123000.000000
# 75%     16.500000  15.000000  11.580000   0.080000  230675.000000
# max     19.250000  20.000000  14.620000   0.730000  434746.000000
#
#          Age_zscore
# count  6.500000e+01
# mean  -2.732857e-17
# std    1.007782e+00
# min   -1.193705e+00
# 25%   -8.964222e-01
# 50%   -5.991393e-01
# 75%    1.035916e+00
# max    1.779124e+00

# %% [markdown]
# # Answer to the eight question
#
# Normalize the age of properties by z−score normalization using mean absolute deviation instead of standard deviation.
#
# df['Age_zscore'].mad()
#
# we have normalised using zscore and mean absolute deviation.The mean absolute deviation is also almost 1.

# %%
df['Age_zscore'].mad()
# Out:
# 0.9609448820279279

# %% [markdown]
# # Answer to the nineth question and the final answer
# (i) Comment on the methods you used in (g) and (h).
#
# From the values from g and h ,the mean absolute deviation is lower than the standard deviation

# %%
# lets import python packages for our project
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# lets load our data
df = pd.read_excel("C:\\Users\\user\\Desktop\\Book1.xlsx")

# %%
# lets read the first five rows
df.head()
# Out:
#    RentalRate  Age  Expense  Vacancy  Footage
# 0      18.750   16    12.86     0.00   421000
# 1      13.750   16    11.13     0.06   153947
# 2      15.625    3     9.10     0.00   184000
# 3      15.000    2     9.75     0.03    38533
# 4      14.500    4     5.31     0.00    70000

# %%
# lets read the last five rows
df.tail()
# Out:
#     RentalRate  Age  Expense  Vacancy  Footage
# 60      14.000   11     8.97     0.07    60000
# 61      13.750    1     4.82     0.00    32000
# 62      17.225    2    12.01     0.03   265500
# 63      15.000   16    10.73     0.09   276099
# 64      14.000    2     7.96     0.22    97321

# %%
# more details about our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RentalRate  65 non-null     float64
#  1   Age         65 non-null     int64
#  2   Expense     65 non-null     float64
#  3   Vacancy     65 non-null     float64
#  4   Footage     65 non-null     int64
# dtypes: float64(3), int64(2)
# memory usage: 2.7 KB

# %%
# This is the general statistics of the whole data
df.describe()
# Out:
#        RentalRate        Age    Expense    Vacancy        Footage
# count   65.000000  65.000000  65.000000  65.000000      65.000000
# mean    15.170769   8.030769   9.602308   0.074615  151664.907692
# std      1.604325   6.779955   2.653303   0.139531  105557.951613
# min     10.500000   0.000000   3.000000   0.000000   27000.000000
# 25%     14.000000   2.000000   7.960000   0.000000   60000.000000
# 50%     15.000000   4.000000  10.380000   0.030000  123000.000000
# 75%     16.500000  15.000000  11.580000   0.080000  230675.000000
# max     19.250000  20.000000  14.620000   0.730000  434746.000000

# %%
# lets get the mean
df['RentalRate'].mean()
# Out:
# 15.170769230769231

# %%
# lets get the median
df['RentalRate'].median()
# Out:
# 15.0

# %%
# lets get the statndard deviation
df['RentalRate'].std()
# Out:
# 1.6043250213215718
